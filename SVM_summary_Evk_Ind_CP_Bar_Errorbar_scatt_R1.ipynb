# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# %% [markdown]
# ## Evoked Induced

# %%
# plt.figure(figsize=(20,10))
n_groups = 4
cp_evk=[57.5,40.0,62.5,46.2]; #rs=11
cp_ind=[47.5,55.0,67.5,72.5];# rs=23
#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'16'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, cp_evk, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Evoked')
 
rects2 = plt.bar(index + bar_width, cp_ind, bar_width,
                 alpha=opacity,
                 color='gray',
                 label='Induced') 
# rects3 = plt.bar(index + bar_width*2, cladalh, bar_width,
#                  alpha=opacity,
#                  color='k',
#                  label='AdaBoost')
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('Whole-brain',**axis_font)
plt.ylim(0,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14,loc='lower center')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'Arial'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Evoked Induced
# #### with replacement 100 smaples[here we drop subject <font color='red'>S1(15)<\font) and S10(25)]

# %%
# plt.figure(figsize=(20,10))
n_groups = 4
# cp_evk=[67.53,68.40,68.92,67.36]; #rs=21
# cp_evk=[67.09,69.29,70.31,64.23]; #rs=16
cp_evk=[67.53,67.88,69.61,66.66]; #rs=24
cp_ind=[90.97,89.06,93.23,94.96];# rs=16
#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'18'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, cp_evk, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Evoked')
 
rects2 = plt.bar(index + bar_width, cp_ind, bar_width,
                 alpha=opacity,
                 color='red',
                 label='Induced') 
# rects3 = plt.bar(index + bar_width*2, cladalh, bar_width,
#                  alpha=opacity,
#                  color='k',
#                  label='AdaBoost')
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('Whole-brain',**axis_font)
plt.ylim(50,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14,loc='lower center')
# plt.legend(fontsize=14,loc='best')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ### LH

# %%
# plt.figure(figsize=(20,10))
n_groups = 4
cp_evk=[64.58,63.19,64.75,60.75]; #rs=14
cp_ind=[81.25,76.90,84.20,87.32];# rs=16
#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'18'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, cp_evk, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Evoked')
 
rects2 = plt.bar(index + bar_width, cp_ind, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Induced') 
# rects3 = plt.bar(index + bar_width*2, cladalh, bar_width,
#                  alpha=opacity,
#                  color='k',
#                  label='AdaBoost')
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('LH',**axis_font)
plt.ylim(50,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14,loc='best')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ## RH

# %%
# plt.figure(figsize=(20,10))
cp_evk=[61.11,62.67,57.98,57.98]; #rs=14
cp_ind=[84.72,81.07,83.15,80.72];# rs=16
n_groups = len(cp_evk)
#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'18'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, cp_evk, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Evoked')
 
rects2 = plt.bar(index + bar_width, cp_ind, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Induced') 
# rects3 = plt.bar(index + bar_width*2, cladalh, bar_width,
#                  alpha=opacity,
#                  color='k',
#                  label='AdaBoost')
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('RH',**axis_font)
plt.ylim(50,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14,loc='best')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ## bar chart with error bar

# %%
# # plt.figure(figsize=(20,10))
# cp_evk=[61.11,62.67,57.98,57.98]; #rs=18 
# cp_ind=[84.72,81.07,83.15,80.72];# rs=
# err_evk=[0.8,0.9,]
# n_groups = len(cp_evk)
# #Manually data
# # clear = [61.29,54.84,54.84,51.29]
# # noise = [59.38,59.38,59.38,53.12]
# # create plot
# axis_font = {'fontname':'Arial', 'size':'18'}
# fig, ax = plt.subplots()
# index = np.arange(n_groups)
# bar_width = 0.30
# opacity = 0.85
 
# rects1 = plt.bar(index, cp_evk, bar_width,
#                  alpha=opacity,
#                  color='b',
#                  label='Evoked')
 
# rects2 = plt.bar(index + bar_width, cp_ind, bar_width,
#                  alpha=opacity,
#                  color='r',
#                  label='Induced') 
# # rects3 = plt.bar(index + bar_width*2, cladalh, bar_width,
# #                  alpha=opacity,
# #                  color='k',
# #                  label='AdaBoost')
# plt.xlabel('Frequency band',**axis_font)
# plt.ylabel('Accuracy (%)',**axis_font)
# plt.title('RH',**axis_font)
# plt.ylim(50,100)
# #plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
# plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
# plt.yticks(**axis_font)
# plt.legend(fontsize=14,loc='best')
# plt.tight_layout()
# plt.show()
# #fig.savefig('LH_band.png')

# %% [markdown]
# ## Error bar

# %% [markdown]
# ## Whole-brain

# %% [markdown]
# ###### '1' for evoked and '2' for induced (e.g., w1,lh1, rh1, w2,etc)

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.4
# Choose the height of the blue bars
# cp_evk=[67.53,67.88,69.61,66.66]; #rs=24
barsw1 = [62.25,61.96,64.13,61.20]
 
# Choose the height of the cyan bars
barsw2 = [88.26, 87.39, 91.94, 93.24]
 
# Choose the height of the error bars (bars1)
yerw1 = [2.04,1.49,1.77,1.61]/np.sqrt(4)
 
# Choose the height of the error bars (bars2)
yerw2 = [1.23, 1.46, 1.18,1.55]/np.sqrt(5)
 
# The x position of bars
rw1 = np.arange(len(barsw1))
rw2 = [x + barWidth for x in rw1]
 
# Create blue bars
plt.bar(rw1, barsw1, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yerw1, capsize=8, label='Evoked')
 
# Create cyan bars
plt.bar(rw2, barsw2, width = barWidth, color = 'r', edgecolor = 'black', yerr=yerw2, capsize=8, label='Induced')
 
# general layout
plt.xticks([r + barWidth-0.2 for r in range(len(barsw1))], [r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'],**axis_font)
plt.yticks(**axis_font)
plt.ylabel('Accuracy (mean' u'±' 'SEM)',**axis_font)
plt.xlabel('Frequency-band', **axis_font)
plt.title('Whole-brain',**axis_font)
plt.legend(fontsize=14,loc='best')
plt.ylim(50,100)
# Show graphic
plt.show()

# %% [markdown]
# ## LH

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.4
# Choose the height of the blue bars
# cp_evk=[64.58,63.19,64.75,60.75]; #rs=14
barslh1 = [60.13,60.28,63.20,57.19]
 
# Choose the height of the cyan bars
# cp_ind=[81.25,76.90,84.20,87.32];# rs=16
barslh2 = [78.90,74.68, 82.27, 85.08]
 
# Choose the height of the error bars (bars1)
yerlh1 = [1.30,1.39,1.46,0.083]/np.sqrt(5)
 
# Choose the height of the error bars (bars2)
yerlh2 = [1.49,1.62,1.34,1.19]/np.sqrt(5)
 
# The x position of bars
rlh1 = np.arange(len(barslh1))
rlh2 = [x + barWidth for x in rlh1]
 
# Create blue bars
plt.bar(rlh1, barslh1, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yerlh1, capsize=8, label='Evoked')
 
# Create cyan bars
plt.bar(rlh2, barslh2, width = barWidth, color = 'r', edgecolor = 'black', yerr=yerlh2, capsize=8, label='Induced')
 
# general layout
plt.xticks([r + barWidth-0.2 for r in range(len(barslh1))], [r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'],**axis_font)
plt.yticks(**axis_font)
plt.ylabel('Accuracy (mean' u'±' 'SEM)',**axis_font)
plt.xlabel('Frequency-band', **axis_font)
plt.title('LH',**axis_font)
plt.legend(fontsize=14,loc='best')
plt.ylim(50,100)
# Show graphic
plt.show()

# %% [markdown]
# ### RH Error bar

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.4
# Choose the height of the blue bars
#cp_evk=[61.11,62.67,57.98,57.98]; #rs=14
barsrh1 = [58.58,60.98, 57.90, 57.92,]
 
# Choose the height of the cyan bars
#cp_ind=[84.72,81.07,83.15,80.72];# rs=16
barsrh2 = [82.07,79.78, 81.35, 80.15]
 
# Choose the height of the error bars (bars1)
yerrh1 = [1.32,2.23,1.55,1.17]/np.sqrt(5)
 
# Choose the height of the error bars (bars2)
yerrh2 = [1.34,1.16,1.56,1.32]/np.sqrt(5)
 
# The x position of bars
rrh1 = np.arange(len(barsrh1))
rrh2 = [x + barWidth for x in rrh1]
 
# Create blue bars
plt.bar(rrh1, barsrh1, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yerrh1, capsize=8, label='Evoked')
 
# Create cyan bars
plt.bar(rrh2, barsrh2, width = barWidth, color = 'r', edgecolor = 'black', yerr=yerrh2, capsize=8, label='Induced')
 
# general layout
plt.xticks([r + barWidth-0.2 for r in range(len(barsrh1))], [r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'],**axis_font)
plt.yticks(**axis_font)
plt.ylabel('Accuracy (mean' u'±' 'SEM)',**axis_font)
plt.xlabel('Frequency-band', **axis_font)
plt.title('RH',**axis_font)
plt.legend(fontsize=14,loc='best')
plt.ylim(50,100)
# Show graphic
plt.show()

# %% [markdown]
# ### The Enddddddddddddddddddddddd

# %%
Stop

# %%
pathclsvm="/home/sultan/EEG/Source_level_frequency_analysis/Results/16Clear_band.csv"
pathclknn="/home/sultan/EEG/Source_level_frequency_analysis/Results/18_knn_Clear_band.csv"
pathclada=pathcl="/home/sultan/EEG/Source_level_frequency_analysis/Results/17_Adaboost_Clear_band.csv"
# pathno="/home/sultan/EEG/Source_level_frequency_analysis/Results/30Noise_band.csv"

# %%
dataclsvm=pd.read_csv(pathclsvm)
dataclknn=pd.read_csv(pathclknn)
dataclada=pd.read_csv(pathclada)

# %%
alld=pd.concat([dataclsvm, dataclknn, dataclada],axis=1)
alld

# %% [markdown]
# ### Whole-brain, LH and RH all band features together

# %%
clsvmab=dataclsvm.iloc[1,1:]; ## column index 1 for whole brain. 2 for LH and 3 for RH
clknnab=dataclknn.iloc[1,1:];# clsvmab: clear svm al brands
cladaab=dataclada.iloc[1,1:];

# %%
# plt.figure(figsize=(20,10))
n_groups = 3

#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'16'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, clsvmab, bar_width,
                 alpha=opacity,
                 color='g',
                 label='SVM')
 
rects2 = plt.bar(index + bar_width, clknnab, bar_width,
                 alpha=opacity,
                 color='gray',
                 label='KNN') 
rects3 = plt.bar(index + bar_width*2, cladaab, bar_width,
                 alpha=opacity,
                 color='k',
                 label='AdaBoost')
plt.xlabel('Analysis scenarios',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('All spectral features (clear)',**axis_font)
plt.ylim(40,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, ('Whole-brain','LH', 'RH'),**axis_font)
# plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
# plt.legend(fontsize=14,loc='center')
plt.legend(fontsize=14,loc='lower center')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ### Whole brain with different frequency band

# %%
clsvmw=dataclsvm.iloc[3:,1]; ## Row 3: means after row 3 all data. column index 1 for whole brain,2: LH, 3: RH
clknnw=dataclknn.iloc[3:,1]
cladaw=dataclada.iloc[3:,1];

# %%
# plt.figure(figsize=(20,10))
n_groups = 4

#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'16'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, clsvmw, bar_width,
                 alpha=opacity,
                 color='g',
                 label='SVM')
 
rects2 = plt.bar(index + bar_width, clknnw, bar_width,
                 alpha=opacity,
                 color='gray',
                 label='KNN') 
rects3 = plt.bar(index + bar_width*2, cladaw, bar_width,
                 alpha=opacity,
                 color='k',
                 label='AdaBoost')
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('Whole-brain (clear)',**axis_font)
plt.ylim(40,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14,loc='lower center')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ## LH

# %%
clsvmlh=dataclsvm.iloc[3:,2]; ## Row 3: means after row 3 all data. column index 1 for whole brain,2: LH, 3: RH
clknnlh=dataclknn.iloc[3:,2]
cladalh=dataclada.iloc[3:,2];

# %%
# plt.figure(figsize=(20,10))
n_groups = 4

#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'16'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, clsvmlh, bar_width,
                 alpha=opacity,
                 color='g',
                 label='SVM')
 
rects2 = plt.bar(index + bar_width, clknnlh, bar_width,
                 alpha=opacity,
                 color='gray',
                 label='KNN') 
# rects3 = plt.bar(index + bar_width*2, cladalh, bar_width,
#                  alpha=opacity,
#                  color='k',
#                  label='AdaBoost')
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('LH (clear)',**axis_font)
plt.ylim(40,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14,loc='lower center')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ## RH

# %%
clsvmrh=dataclsvm.iloc[3:,3]; ## Row 3: means after row 3 all data. column index 1 for whole brain,2: LH, 3: RH
clknnrh=dataclknn.iloc[3:,3];
cladarh=dataclada.iloc[3:,3];

# %%
# plt.figure(figsize=(20,10))
n_groups = 4

#Manually data
# clear = [61.29,54.84,54.84,51.29]
# noise = [59.38,59.38,59.38,53.12]
# create plot
axis_font = {'fontname':'Arial', 'size':'16'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.30
opacity = 0.85
 
rects1 = plt.bar(index, clsvmrh, bar_width,
                 alpha=opacity,
                 color='g',
                 label='SVM')
 
rects2 = plt.bar(index + bar_width, clknnrh, bar_width,
                 alpha=opacity,
                 color='gray',
                 label='KNN') 
rects3 = plt.bar(index + bar_width*2, cladarh, bar_width,
                 alpha=opacity,
                 color='k',
                 label='AdaBoost')
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('RH (clear)',**axis_font)
plt.ylim(40,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index + bar_width, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14,loc='lower center')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
#  ### Thsis is the scatter or line plot

# %%
### Whole brain with different frequency band

# %%
clsvmrh=dataclsvm.iloc[3:,3]; ## Row 3: means after row 3 all data. column index 1 for whole brain,2: LH, 3: RH
clknnrh=dataclknn.iloc[3:,3];
cladarh=dataclada.iloc[3:,3];

# %%
clsvmrh
clknnrh

# %% [markdown]
# #### This is the code for scatter plot

# %%
n_groups = 4
# clear = (61.29,54.83,54.83,61.29)
# noise = (85, 62, 54, 20)
#Random shuffle
clear = [96.24,94.63,92.40]
noise = [92.79,92.24,90.96] 
# create plot
axis_font = {'fontname':'Arial', 'size':'16'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.40
opacity = 0.85
 
rects1 = plt.scatter(index, clsvmrh,marker ='*',color='g',label='Clear',s=200)
rects1 = plt.scatter(index, clknnrh,marker ='p',color='r',label='Noise',s=200)
plt.scatter(index, cladarh,marker ='p',color='k',label='Noise',s=200)
 
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('LH',**axis_font)
plt.ylim(50,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
plt.xticks(index, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14)
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ## line chart

# %%
n_groups = 4
 
# create plot
axis_font = {'fontname':'Arial', 'size':'16'}
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.40
opacity = 0.85
 
plt.plot(index, clsvmrh,'-g',marker ='*',linewidth=2.5)
plt.plot(index, clknnrh,'--r',marker ='o',linewidth=2.5)
plt.plot(index, cladarh,'-*k',marker ='x',linewidth=2.5)
#plt.plot(index, cladarh,marker ='x',color='k',label='RH')
 
plt.xlabel('Frequency band',**axis_font)
plt.ylabel('Accuracy (%)',**axis_font)
plt.title('LH',**axis_font)
plt.ylim(60,100)
#plt.xticks(index + bar_width-0.2, ('Theta','Alpha', 'Beta', 'Gamma'))
# plt.xticks(index + bar_width-0.2, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.xticks(index, (r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'),**axis_font)
plt.yticks(**axis_font)
plt.legend(fontsize=14)
plt.gca().legend(('Whole','LH','RH'),fontsize=16,loc='best')
plt.tight_layout()
plt.show()
#fig.savefig('LH_band.png')

# %% [markdown]
# ### Evoked induced analysis

# %%
import matplotlib.pyplot as plt

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# width of the bars
barWidth = 0.3
 
# Choose the height of the blue bars
bars1 = [10, 9, 2, 10]
 
# Choose the height of the cyan bars
bars2 = [10.8, 9.5, 4.5,12]
 
# Choose the height of the error bars (bars1)
yer1 = [0.5, 0.4, 0.5,.025]
 
# Choose the height of the error bars (bars2)
yer2 = [1, 0.7, 1,0.1]
 
# The x position of bars
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Create blue bars
plt.bar(r1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', yerr=yer1, capsize=7, label='Induced')
 
# Create cyan bars
plt.bar(r2, bars2, width = barWidth, color = 'r', edgecolor = 'black', yerr=yer2, capsize=7, label='evoked')
 
# general layout
plt.xticks([r + barWidth for r in range(len(bars1))], [r'$\theta$',r'$\alpha$', r'$\beta$', r'$\gamma$'])
plt.ylabel('Accuracy',**axis_font)
plt.xlabel('Frequency-band', **axis_font)
plt.legend()
plt.legend(fontsize=14,loc='lower center') 
# Show graphic
plt.show()
